# %%
import pandas as pd
import json

# %%
import redis

redis_client = redis.Redis(host='localhost', port=6399, db=0,decode_responses=True)

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import  Distance, VectorParams

client = QdrantClient(url="http://localhost:6333")

from qdrant_client.models import PointStruct
from uuid import uuid4
import json

import numpy as np

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import pairwise_distances
from scipy.cluster.hierarchy import linkage, fcluster

# Configuration parameters
config = {
    'clustering': {
        'method': 'centroid',
        'min_cluster_size': 3,
        'threshold': 1.#0.7# 0.7045654963945799 #
    }
}



def centroid_linkage_distance(matrix):
    """Custom function to compute linkage with centroid method."""
    Z = linkage(matrix, method='centroid')
    return Z

def compute_centroids(embeddings, labels):
    """Compute centroids of clusters and return centroids in the order of labels."""
    unique_labels = np.unique(labels)
    centroids = np.zeros((len(unique_labels), embeddings.shape[1]))
    
    for i, label in enumerate(unique_labels):
        centroids[i] = embeddings[labels == label].mean(axis=0)
    
    return centroids, unique_labels

def map_labels_to_centroid_indices(labels, unique_labels):
    """Map labels to the indices of centroids."""
    label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
    centroid_indices = np.array([label_to_index[label] if label in unique_labels else -1 for label in labels])
    return centroid_indices

def cluster_embeddings(embeddings, config):
    # Compute pairwise distances
    distance_matrix = pairwise_distances(embeddings, metric='cosine')
    
    # Perform hierarchical clustering with centroid method
    Z = centroid_linkage_distance(distance_matrix)
    
    # Extract clusters based on distance threshold
    labels = fcluster(Z, t=config['clustering']['threshold'], criterion='distance')
    
    # Filter small clusters
    unique_labels, counts = np.unique(labels, return_counts=True)
    valid_labels = unique_labels[counts >= config['clustering']['min_cluster_size']]
    
    # Valid indices based on cluster size
    valid_indices = np.where(np.isin(labels, valid_labels))[0]
    
    # Compute centroids
    centroids, unique_labels = compute_centroids(embeddings, labels)
    
    # Map labels to the indices of centroids
    centroid_indices = map_labels_to_centroid_indices(labels, unique_labels)
    
    # Compute valid centroid indices (subset of centroid_indices)
    valid_centroid_indices = np.array([index for index, centroid in enumerate(centroids) if index in np.unique(centroid_indices[valid_indices])])

    return centroid_indices, centroids, valid_centroid_indices

# %%
def find_largest_span(points):
    # Use max to find the point with the largest span
    largest_span_point = max(points, key=lambda p: p.payload['span'])
    return largest_span_point

# %%
class SpeechDAL:
    def get_all_transcriptions(self) -> list:
        # Get all data
        raw_data = redis_client.lrange(f"transcriber", start=0, end=-1)
        return [json.loads(data) for data in raw_data]

    def get_all_diarizations(self) -> list:
        # Get all data
        raw_data = redis_client.lrange(f"diarizer", start=0, end=-1)
        return [json.loads(data) for data in raw_data]

    def lpush_diarizations(self,diarizations: str) -> None:
        for d in diarizations:
            redis_client.lpush(f"diarizer", json.dumps(d))

    def lpush_transcriptions(self, transcriptions) -> None:
        for t in transcriptions:
            redis_client.lpush(f"transcriber", json.dumps(t))

    def ltrim_transcriptions(self, meeting_id, slice: tuple):
        redis_client.ltrim(f"diarizer", int(slice[0]), int(slice[1]))

    def ltrim_diarizations(self, meeting_id, slice: tuple):
        redis_client.ltrim(f"diarizer", int(slice[0]), int(slice[1]))

# %%
@staticmethod
def prep_transcripts(transcriptions) -> pd.DataFrame:
    dfs = []
    for n, (t, seek) in enumerate(transcriptions):
        df = pd.DataFrame(t)[[2, 3, 4]]
        df.columns = ["start", "end", "speech"]
        df["start"] = pd.to_timedelta(df["start"], unit="s") + pd.Timestamp(seek)
        df["end"] = pd.to_timedelta(df["end"], unit="s") + pd.Timestamp(seek)
        df["trans_chunk"] = n
        dfs.append(df)
    return pd.concat(dfs).reset_index(drop=True)

@staticmethod
def prep_diarization(diarization) -> pd.DataFrame:
    d, embs,seek = diarization
    df = pd.DataFrame(d)
    df["start"] = pd.to_timedelta(df["start"], unit="s") + pd.Timestamp(seek)
    df["end"] = pd.to_timedelta(df["end"], unit="s") + pd.Timestamp(seek)

    return df,embs

# %%
def prep_diarizations(diarizations) -> pd.DataFrame:
    dfs = []
    embs = []
    for n, (d, emb, seek) in enumerate(diarizations):
        df = pd.DataFrame(d)
        df["start"] = pd.to_timedelta(df["start"], unit="s") + pd.Timestamp(seek)
        df["end"] = pd.to_timedelta(df["end"], unit="s") + pd.Timestamp(seek)
        df["diar_chunk"] = n
        dfs.append(df)
        embs.append(emb)
    return pd.concat(dfs).reset_index(drop=True),embs

# %%
from scipy.spatial.distance import squareform

# %%
embeddings_list = [] #redis
segments_df = None
speech_dal = SpeechDAL()
diarizations = speech_dal.get_all_diarizations()

# %%
segments_df,embs = prep_diarizations(diarizations)
embeddings_list.extend(embs)
embeddings = np.concatenate(embeddings_list, axis=0)
clusters,centroids,valid_clusters = cluster_embeddings(embeddings, config)
print(np.unique(clusters))
# Out:
# [0 1 2 3 4 5 6 7]
# /tmp/ipykernel_2990372/2946564393.py:19: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(matrix, method='centroid')

# %%
embs_mapping = segments_df[['diar_chunk','speaker_id']].sort_values(['diar_chunk','speaker_id']).drop_duplicates().set_index(['diar_chunk','speaker_id'])
embs_mapping['emb_id'] = np.arange(len(embs_mapping))
embs_mapping['cluster'] = clusters
segments_df = segments_df.set_index(['diar_chunk','speaker_id']).join(embs_mapping).reset_index().set_index('emb_id').drop(columns = ['speaker_id'])

# %%
segments_df['span'] = segments_df['end'] - segments_df['start']
segments_df['span'] = segments_df['span'].dt.seconds
speakers = segments_df[['cluster']].drop_duplicates().reset_index(drop=True)

cluster_span = segments_df.groupby('cluster')[['span']].sum()
cluster_span = cluster_span.to_dict()['span']
clusters = list(cluster_span.keys())

# %%
clusters
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
new_points = []
for cluster in clusters:
    point_id = None

    centroid = centroids[cluster]
    search_results = client.search(collection_name="speakers", query_vector=list(centroid), limit=5,score_threshold=0.65)
    
    
    
    if len(search_results)==0:
        if cluster in valid_clusters:
            point_id = str(uuid4())
            new_points.append(PointStruct(id = point_id,vector = list(centroid),payload={"span":cluster_span[cluster]}))

    else:
        search_result = find_largest_span(search_results)
        point_id = search_result.id 
        remote_span = search_result.payload['span']
        

        span = cluster_span[cluster]
        if span > remote_span in valid_clusters:
            new_points.append(PointStruct(id = point_id,vector = list(centroid),payload={"span":span}))  
            
            
    segments_df.loc[segments_df['cluster']==cluster,'speaker'] = point_id
    
            
if len(new_points)>0:
    operation_info = client.upsert(
        collection_name="speakers",
        wait=True,
        points=new_points
    )       

segments_df = segments_df.sort_values('start').reset_index(drop=True)
# Out:
# /tmp/ipykernel_2990372/124942946.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '01d8d910-6c0d-436b-a021-b1cfb9e7c1ad' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   segments_df.loc[segments_df['cluster']==cluster,'speaker'] = point_id

# %%
diar_df = segments_df

# %%
def seconds_to_min_sec(seconds):
    minutes = int(seconds // 60)
    seconds = seconds % 60
    return f"{minutes}:{seconds:06.3f}"  # Format to show milliseconds
diar_df['start_'] = (diar_df['start']-diar_df['start'].min()).dt.seconds
diar_df['Start_min_sec'] = diar_df['start_'].apply(seconds_to_min_sec)

# %%
#diar_df = segments_df.groupby('speaker_switch').agg({'start':'first','end':'last','speaker':"first",'diar_chunk':'last'})

# %%
diar_df['span'] = (diar_df['end']-diar_df['start']).dt.seconds

# %%
speech_dal = SpeechDAL()
transcriptions = speech_dal.get_all_transcriptions()

# %%
trans_df = prep_transcripts(transcriptions).sort_values('start')

# %%
# Define a tolerance window (e.g., 2 seconds)
tolerance = pd.Timedelta(seconds=5)

# List to store results
results = []

# Iterate over each row in trans_df
for i, trans_row in trans_df.iterrows():
    max_intersection = pd.Timedelta(0)
    best_speaker = np.nan
    best_diar_chunk = np.nan
    
    # Compare with each row in diar_df
    for j, diar_row in diar_df.iterrows():
        # Calculate potential intersection
        intersection_start = max(diar_row['start'] - tolerance, trans_row['start'] - tolerance)
        intersection_end = min(diar_row['end'] + tolerance, trans_row['end'] + tolerance)
        intersection = intersection_end - intersection_start
        
        # Check if there is a positive intersection
        if intersection > pd.Timedelta(0):
            # If this is the largest intersection found, update speaker
            if intersection > max_intersection:
                max_intersection = intersection
                best_speaker = diar_row['speaker']
                best_diar_chunk = diar_row['diar_chunk']
    
    # Store the result with the best speaker match or nearest match
    result = trans_row.to_dict()
    result['speaker'] = best_speaker
    result['diar_chunk'] = best_diar_chunk
    result['intersection'] = max_intersection
    results.append(result)

# Convert results to DataFrame
merged_df = pd.DataFrame(results)

# %%
merged_df
# Out:
#                               start                              end  \
# 0  2024-06-21 12:36:33.368864+00:00 2024-06-21 12:36:36.108864+00:00
# 1  2024-06-21 12:36:37.248864+00:00 2024-06-21 12:36:39.268864+00:00
# 2  2024-06-21 12:36:42.108864+00:00 2024-06-21 12:36:44.688864+00:00
# 3  2024-06-21 12:36:44.708864+00:00 2024-06-21 12:36:47.548864+00:00
# 4  2024-06-21 12:36:48.668864+00:00 2024-06-21 12:36:50.128864+00:00
# 5  2024-06-21 12:36:51.408864+00:00 2024-06-21 12:36:53.148864+00:00
# 6  2024-06-21 12:36:53.258864+00:00 2024-06-21 12:36:55.498864+00:00
# 7  2024-06-21 12:36:55.518864+00:00 2024-06-21 12:36:58.058864+00:00
# 44 2024-06-21 12:40:45.178864+00:00 2024-06-21 12:40:46.778864+00:00
# 45 2024-06-21 12:40:46.898864+00:00 2024-06-21 12:40:49.218864+00:00
# 46 2024-06-21 12:40:51.008864+00:00 2024-06-21 12:40:53.248864+00:00
# 47 2024-06-21 12:40:53.258864+00:00 2024-06-21 12:41:08.708864+00:00
# 48 2024-06-21 12:41:08.708864+00:00 2024-06-21 12:41:12.568864+00:00
# 49 2024-06-21 12:41:13.498864+00:00 2024-06-21 12:41:14.218864+00:00
# 50 2024-06-21 12:41:34.138864+00:00 2024-06-21 12:41:42.218864+00:00
# 51 2024-06-21 12:41:42.218864+00:00 2024-06-21 12:41:52.998864+00:00
# 52 2024-06-21 12:41:53.258864+00:00 2024-06-21 12:41:56.838864+00:00
# 53 2024-06-21 12:41:59.198864+00:00 2024-06-21 12:42:07.258864+00:00
# 54 2024-06-21 12:42:08.478864+00:00 2024-06-21 12:42:13.098864+00:00
# 55 2024-06-21 12:42:13.258864+00:00 2024-06-21 12:42:31.238864+00:00
# 56 2024-06-21 12:42:33.818864+00:00 2024-06-21 12:42:41.078864+00:00
# 57 2024-06-21 12:42:41.078864+00:00 2024-06-21 12:42:48.198864+00:00
# 58 2024-06-21 12:42:48.198864+00:00 2024-06-21 12:42:51.218864+00:00
# 59 2024-06-21 12:42:53.258864+00:00 2024-06-21 12:43:13.258864+00:00
#
#                                                speech  trans_chunk  \
# 0         Что у нас с тобой по спикерам? Пройдем все.           19
# 1                     По спикерам давай, по диарайзу.           19
# 2    Последний день перед отпуском на основной раб...           19
# 3        Блин, то по носу, то золотом. Все мое, блин.           19
# 4                              У тебя два дня отпуск?           19
# 5                     Нет, у меня четыре со вторника.           19
# 6                      по пятницу на основной работе,           18
# 7                                   а здесь я отдохну           18
# 8          в среду, в четверг, завтра я в строю буду.           18
# 9                                                Ага.           18
# 10                                              Окей.           18
# 11                                     Так, ну ладно.           18
# 12                                      Так, ну давай           18
# 13                                   просто посмотрим           18
# 14                                               код.           18
# 15   и подумают, что с ним делать, например, вот так.           17
# 16                                        Угу, давай.           17
# 17                                          Ага, все.           17
# 18                           Вот, что у нас тут есть?           17
# 19   Ну, у нас есть вот этот вектор store, который...           17
# 20                 в отдельном в отдельном контейнере           16
# 21   как обычно это нам здесь нужно так чисто для ...           16
# 22             Это все там, где ты скинул, да, в 0.2.           15
# 23   Да, здесь все, здесь end-to-end все есть. Вот...           15
# 24   Вот, видишь, получил какое-то, вот какие-то л...           14
# 25   И вот этот вот уже кластер, который есть, это...           13
# 26   Вот. Идем дальше. Лиза что-то говорит. Лиза, ...           12
# 27                                        На секунду.           11
# 28                         Да, но он не успел понять.           11
# 29                             Это подача на систему.           11
# 30                           Ну, это однозначно Лиза.           11
# 31    Да, ну вот дальше Лиза, Лиза, Лиза, Лиза, Лиза.           11
# 32            Ну вот, кто-то опять что-то там сказал.           11
# 33                                      Или это 28...           11
# 34   Ну, тут понятно, тут будут, мне, наверное, ну...           10
# 35   Мачется с транскрипциями. Вот видишь, ну вот ...            9
# 36   например может быть она неправильно запустила...            8
# 37   запустила ту предыдущую она вот здесь вот он ...            8
# 38   кластер кластер маленький поэтому нам вот зде...            8
# 39           кто-то новый говорит, кого он не слышал.            7
# 40                        Видишь, одинаковый ID-шник.            7
# 41                                     Что это такое?            7
# 42                                       Это снижение            7
# 43                                     из интеграции.            7
# 44                              Я узнаю этого чувака.            7
# 45                                         Это Дэвид.            7
# 46                                         Это Дэвид.            7
# 47   Дэвид, Дэвид, я его запишу как Дэвид, возьму ...            6
# 48   распознать, потому что здесь я тоже в этой вс...            6
# 49                                            встречу            5
# 50   а это кусочек этой встречи сюда закинул вот н...            4
# 51   посмотрю как это мочится с виспером вот в цел...            4
# 52       Что здесь нам нужно сделать? Давай прикинем.            3
# 53   Ну смотри, в идеале для начала определиться, ...            3
# 54    Она заканчивается раньше, чем до этого сервиса.            3
# 55   Сейчас она будет возвращать, вот видишь, вот ...            2
# 56   но смотря на аудио сервисе до этого имбединги...            1
# 57   тут видишь я до этого за аудио сервису сейчас...            1
# 58                            вытаскивал имбединги из            1
# 59   Из этого самого, из VectorStore. Здесь будет ...            0
#
#                                  speaker  diar_chunk              intersection
# 0   01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        19.0 0 days 00:00:12.400084890
# 1   2326f850-4157-4f2a-b826-e87318c1b942        19.0 0 days 00:00:11.281646859
# 2   2326f850-4157-4f2a-b826-e87318c1b942        19.0    0 days 00:00:12.580000
# 3   2326f850-4157-4f2a-b826-e87318c1b942        19.0 0 days 00:00:12.040424448
# 4   01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        19.0 0 days 00:00:10.885280136
# 5   01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        19.0 0 days 00:00:11.494414261
# 6   2326f850-4157-4f2a-b826-e87318c1b942        18.0 0 days 00:00:12.231511036
# 7   2326f850-4157-4f2a-b826-e87318c1b942        18.0    0 days 00:00:12.540000
# 8   2326f850-4157-4f2a-b826-e87318c1b942        18.0    0 days 00:00:11.700000
# 9   01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:10.362376910
# 10  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:10.409473684
# 11  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:10.744210526
# 12  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:10.681765705
# 13  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0    0 days 00:00:11.120000
# 14  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0    0 days 00:00:10.540000
# 15  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:10.110356537
# 16  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:07.130356537
# 17  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        18.0 0 days 00:00:01.790356537
# 18  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:02.771511036
# 19  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:07.691511036
# 20  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:13.276740238
# 21  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:17.402376910
# 22  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:09.616400679
# 23  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        17.0 0 days 00:00:06.016400679
# 24  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        16.0 0 days 00:00:09.771511036
# 25  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        16.0 0 days 00:00:17.724957555
# 26  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        16.0 0 days 00:00:09.456400679
# 27                                   NaN         NaN           0 days 00:00:00
# 28                                   NaN         NaN           0 days 00:00:00
# 29                                   NaN         NaN           0 days 00:00:00
# 30                                   NaN         NaN           0 days 00:00:00
# 31                                   NaN         NaN           0 days 00:00:00
# 32                                   NaN         NaN           0 days 00:00:00
# 33                                   NaN         NaN           0 days 00:00:00
# 34  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        15.0 0 days 00:00:09.661511036
# 35  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        15.0 0 days 00:00:16.960950764
# 36  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        15.0 0 days 00:00:09.550356537
# 37  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        15.0 0 days 00:00:04.430356537
# 38                                   NaN         NaN           0 days 00:00:00
# 39                                   NaN         NaN           0 days 00:00:00
# 40                                   NaN         NaN           0 days 00:00:00
# 41                                   NaN         NaN           0 days 00:00:00
# 42                                   NaN         NaN           0 days 00:00:00
# 43                                   NaN         NaN           0 days 00:00:00
# 44                                   NaN         NaN           0 days 00:00:00
# 45                                   NaN         NaN           0 days 00:00:00
# 46                                   NaN         NaN           0 days 00:00:00
# 47                                   NaN         NaN           0 days 00:00:00
# 48                                   NaN         NaN           0 days 00:00:00
# 49                                   NaN         NaN           0 days 00:00:00
# 50  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        14.0 0 days 00:00:14.974533108
# 51  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        14.0 0 days 00:00:13.500611205
# 52  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        14.0 0 days 00:00:10.076400679
# 53  01d8d910-6c0d-436b-a021-b1cfb9e7c1ad        14.0 0 days 00:00:04.136400679
# 54                                   NaN         NaN           0 days 00:00:00
# 55                                   NaN         NaN           0 days 00:00:00
# 56                                   NaN         NaN           0 days 00:00:00
# 57                                   NaN         NaN           0 days 00:00:00
# 58                                   NaN         NaN           0 days 00:00:00
# 59                                   NaN         NaN           0 days 00:00:00

# %%
diar_df
# Out:
#      diar_chunk                               start  \
# 0            19 2024-06-21 12:36:33.267352964+00:00
# 1            19 2024-06-21 12:36:36.730850418+00:00
# 2            19 2024-06-21 12:36:40.907420876+00:00
# 3            19 2024-06-21 12:36:41.179067735+00:00
# 4            19 2024-06-21 12:36:42.876860604+00:00
# ..          ...                                 ...
# 106           0 2024-06-21 13:39:55.050035477+00:00
# 107           0 2024-06-21 13:39:57.223210350+00:00
# 108           0 2024-06-21 13:40:09.294517650+00:00
# 109           0 2024-06-21 13:40:11.841206954+00:00
# 110           0 2024-06-21 13:40:12.554279959+00:00
#
#                                     end  cluster  span  \
# 0   2024-06-21 12:36:36.170578771+00:00        0     2
# 1   2024-06-21 12:36:40.720663660+00:00        0     3
# 2   2024-06-21 12:36:41.348847022+00:00        6     0
# 3   2024-06-21 12:36:42.554279959+00:00        0     1
# 4   2024-06-21 12:36:53.352242608+00:00        0    10
# ..                                  ...      ...   ...
# 106 2024-06-21 13:39:56.798762132+00:00        0     1
# 107 2024-06-21 13:40:09.022870791+00:00        0    11
# 108 2024-06-21 13:40:10.550884374+00:00        0     1
# 109 2024-06-21 13:40:12.316588958+00:00        0     0
# 110 2024-06-21 13:40:13.335264679+00:00        0     0
#
#                                   speaker  start_ Start_min_sec
# 0    dac38808-0f6d-42c5-a0fc-b355e453db00       0      0:00.000
# 1    dac38808-0f6d-42c5-a0fc-b355e453db00       3      0:03.000
# 2                                    None       7      0:07.000
# 3    dac38808-0f6d-42c5-a0fc-b355e453db00       7      0:07.000
# 4    dac38808-0f6d-42c5-a0fc-b355e453db00       9      0:09.000
# ..                                    ...     ...           ...
# 106  dac38808-0f6d-42c5-a0fc-b355e453db00    3801     63:21.000
# 107  dac38808-0f6d-42c5-a0fc-b355e453db00    3803     63:23.000
# 108  dac38808-0f6d-42c5-a0fc-b355e453db00    3816     63:36.000
# 109  dac38808-0f6d-42c5-a0fc-b355e453db00    3818     63:38.000
# 110  dac38808-0f6d-42c5-a0fc-b355e453db00    3819     63:39.000
#
# [111 rows x 8 columns]

# %%
segments = trans_df.to_dict("records")

# %%
segments = trans_df.to_dict("records")

if len(segments) > 0:
    for seg in segments:
        diar_df["intersection"] = np.minimum(diar_df["end"], seg["end"]) - np.maximum(
            diar_df["start"], seg["start"]
        )
        speaker_ = diar_df[
            (diar_df["intersection"] == diar_df["intersection"].max())
            & (diar_df["intersection"] > pd.Timedelta(0))
        ][["speaker", "diar_chunk"]]
        if len(speaker_) > 0:
            seg["speaker"] = speaker_["speaker"].iloc[0]


        # ToDo: Dima
        else:
            seg["speaker"] = np.nan

# %%
diar_df.head(2)
# Out:
#    diar_chunk                               start  \
# 0          19 2024-06-21 12:36:33.267352964+00:00
# 1          19 2024-06-21 12:36:36.730850418+00:00
#
#                                   end  cluster  span  \
# 0 2024-06-21 12:36:36.170578771+00:00        0     2
# 1 2024-06-21 12:36:40.720663660+00:00        0     3
#
#                                 speaker  start_ Start_min_sec  \
# 0  dac38808-0f6d-42c5-a0fc-b355e453db00       0      0:00.000
# 1  dac38808-0f6d-42c5-a0fc-b355e453db00       3      0:03.000
#
#                  intersection
# 0 -1 days +23:53:29.851714771
# 1 -1 days +23:53:34.401799660

# %%
trans_df.head(2)
# Out:
#                               start                              end  \
# 7                                                                                                                                                                                                                                                                                                                                      что вам делать при дискавери, да, как бы. Я говорю, мы можем вам за счет
# 8                                                                                                                                   пару вопросов задать типа перед встречей, там типа знаешь, как мы делали, couple questions before the meeting if you don't mind, и у них задача такая, они хотят максимально быстро закрыть какое-то количество deals и как бы нас использовать как вот таких квалифаеров и
# 9                                                                                    типа сорсеров, лидов, я им сказал, как ты помнишь, на звонке, я говорю, блядь, это все заебись, но мы вообще интерпрайз, ребята, мы вообще, блядь, настроены на большой чек нахуй, и нам, как бы, нужен, как бы, ROI такой довольно long term, и он выше намного, поэтому и мы чарлить хотим у вас больше денег в будущем.
# 10                                                                                                                                                                                                                                                                                                                                  Но, видимо, чуваки, как бы, пока что не готовы к этой модели, потому что...
# 11   не сильно верят в себя еще, потому что они сказали о том, что типа вот мы ни хуя не понимаем, как будем работать с CIG, как мы будем продавать большим компаниям типа Udeliver или Pepsi, и соответственно, вот видишь, они нам говорят, давайте-ка нахуй отставим это чуть-чуть в сторону, и будем работать типа с компаниями, которые типа direct purchasers, и это намного быстрее, типа действительно.
# 12                                                                                                                   Ну, как ты понял, нахуй дистрибьюторов, блядь, не миллиард, а особенно, сука, в регионах, типа, там, где они хотели, Азербайджан или Казахстан, их, блядь, нихуя нет. Ну, то есть, там есть какие-то абсолютно рандомные конторы, либо, типа, пару нормальных контор и все. Ну, правильно?
# 13                                                                                                                                                                                                                                                                                                                                                                                    Да, у меня все правильно.
# 14                                                                                                                                                                                                                                                                                                           ну явно идея уёбищна то есть как бы по идее мы можем конечно поставить со всеми которые у нас есть
# 15                                                                                                                                                                                                                                                                                                                                  еще больше но по итогам катаются типа 10 встреч типа тот опасается 15 будет
# 16                                                                                                                                                                                                                              Поэтому, что я тебе сказал, я тебя попросил, давай, Саня, расширим географию, возьмем, блядь, Балтику там, Полон, короче, все остальное. Я думаю, что мы сейчас подстраиваем...
# 17                                                                                                  сейчас поставим эти дистрибьюторы я короче за выходные посмотрю что это за компания которая там засорсил я посмотрю типы людей ЛПР и там как что я докручу месседж я сначала сам начну Саш дай мне там 3-5 дней я за полипедию короче сам и дальше мы с тобой встретимся я тебе скажу как у меня получилось
# 18                                                                                                                            И дальше тебе выдам какую-то, блядь, часть рекомендации, ты уже сам там смотри, как ты хочешь, блядь, этим крутить-вертеть, и, соответственно, мы должны с тобой понять, блядь, а, сколько этих, блядь, долбоёбов вообще в мире дистрибьюторов, и есть ли там нормальные конторы.
# 19                                                                                                                                                                                                                                                                                                                                                                                      Ты вот когда смотрел...
# 20                                                                                                                                                                                                                                                                                                                                                                                                 Вот смотрел.
# 21                                                                                                                                                                                                                                                                                                                                                       Давай я сейчас быстро прокомментирую все, что сказано.
# 22                                                                                                                                                                                                                                                                                                                 Короче, я начал поиск, и это вообще полная ебля вообще на самом деле с этими дистрибуторами,
# 23                                                                                                                                                                                                                                                                                                                                                      потому что они не представлены в LinkedIn многие части.
# 24                                                                                                                                                                                                                                                                                                                    То есть я большую часть поискал просто через Google, и пытаюсь искать в LinkedIn полтора.
# 25                                                            землекопа. Три с половиной человека там работают, дай бог. Некоторых вообще просто нет никуда. Некоторые компашки, вот там просто один человек какой-нибудь, не пойми кто вообще. Но я им просто такой, ладно, записываю, просто думаю, может быть, как-нибудь по-другому к ним подберемся. И начал поиск вообще в итоге по другой истории, что я
# 26                                                                                                                                                                                                                                                                                                                                   просто знаешь именно дистрибутеры fmcg дистрибутеры которые есть линкедыни
# 27                                                                                                                                                                                                                                                                                                                              вот я вот пока нашел по европе вот он не выдает по одни вот гитаре им около 200
# 28                                                                                                                                                                                                                                                                                                                                  компаний и то из них ну как бы там не знаю процентов 30 наверно можно сразу
# 29                                                                                                                                                                                                                                                                                                                                  отсечься скорее всего там но поиск иногда в линкедыне работать так себе еще
# 30                                                                                                                                                                                                                                                                                                                                                                               Бля, ну хуёво, бро, это хуёво.
# 31                                                                                                                                                                         План у нас такой, я сейчас посмотрю на весь твой список, посмотрю там что за компании, выделю оттуда 15-20 компаний, по моему мнению, с которыми можно сделать встречи, мы их выделим зеленым, там выпишем людей, которые нам нужны.
# 32                                                                                                                                                                                                                                                                                                                                            Поставим встречи, типа штук 10 встреч поставим с дистрибьюторами.
# 33                                                                                                                                                                                                                                                                                                                                               И дальше поймем, блядь, как у них идут дела с дистрибьюторами.
# 34                                                                                                                                                                                                                                                                                                                                                             Если у них дела идут с дистрибьюторами, охуенно.
# 35                                                                                                                                                                                                                                                                                                                                  Мы расширим этот пайплайн дистрибьюторов на, блядь, все европейские страны,
# 36                                                                                                                                                                                                                                                                                                                                                                  которые мы, нахуй, можем найти, в принципе.
# 37                                                                                                                                                                                                                                                                                                                               То есть, блядь, на всю Европу и, может быть, даже, блядь, шире, там, на Тур...
# 38                                                                                                                                                                                                                                                                                                                                                                              ебаный, типа, и дальше, как бы.
# 39                                                                                                                                                                                                                                                                                                                                                                           И за эти два месяца они попиздятся
# 40                                                                                                                                                                                                                                                                                                                                                                                 всеми этими дистрибьюторами,
# 41                                                                                                                                                                                                                                                                                                                                                               и, как бы, скажут нам, ребята, мы хотим только
# 42                                                                                                                                                                                                                                                                                                                                                                     дистрибьюторов, все охуенно. Либо скажут
# 43                                                                                                                                                                                                                                                                                                                                                                      нам, ребята, да вы такие охуенные типы,
# 44                                                                                                                                                                                                                                                                                                                                                                             а давайте нам еще с FMCG встречи
# 45                                                                                                                                                                                                                                                                                                                                                                          поставим, а дальше начинается какая
# 46                                                                                                                                                                                                                                                                                                                                                                                         хуйня. FMCG-то есть,
# 47                                                                                                                                                                                                                                                                                                                                                                       блядь, не такие большие, как Unilever,
# 48                                                                                                                                                    Если 500 человек работают или 1000, соответственно, я предлагаю сейчас им подстраивать дистрибьютора пару недель, а дальше еще пару недель поставить им FMCG, которые манифакшируются, но не такие большие, типа 500-5000 человек, и понять, насколько...
# 49                                                                                                                                                                                                                                                                      Там есть жизнь. И дальше они с вот этой инфой к нам придут и скажут, что, ребята, все охуенно, мы вообще хотим и FNCG, и дистрибьютора.
# 50                                                                                                                                                                                                                                                                     Но если они нам скажут, блядь, ребята, идите нахуй, нам нужен только дистрибьютор, и мы вообще ничего не можем продавать в манифакчерах,
# 51                                                                                                                                                                                                                                             то у нас, блядь, long-term проблема, потому что мы, как бы, будем работать с чуваками, где, блядь, типа, жизнь этих людов, она, блядь, закончится в один момент.
# 52                                                                                                                                                                                                                                                                                                                         либо либо они будут смотреть на нас как на блять вот этих аутсорсеров который ебашит
# 53                                                                                                                                                                                                                                                                                                                       просто лист блять вот этих дистрибьюторов и всем хуярят просто типа автоматизированную
# 54                                                                                                                                                                                                                                                                                                                            цепочку сообщений типа но это smb блять и мы им скажем ребята типа мы им нахуй не
#
#     trans_chunk                               speaker
# 0            19  dac38808-0f6d-42c5-a0fc-b355e453db00
# 1            19  dac38808-0f6d-42c5-a0fc-b355e453db00
# 2            19  dac38808-0f6d-42c5-a0fc-b355e453db00
# 3            18  dac38808-0f6d-42c5-a0fc-b355e453db00
# 4            18  dac38808-0f6d-42c5-a0fc-b355e453db00
# 5            18  dac38808-0f6d-42c5-a0fc-b355e453db00
# 6            18  dac38808-0f6d-42c5-a0fc-b355e453db00
# 7            18  dac38808-0f6d-42c5-a0fc-b355e453db00
# 8            17                                   NaN
# 9            16  dac38808-0f6d-42c5-a0fc-b355e453db00
# 10           16  dac38808-0f6d-42c5-a0fc-b355e453db00
# 11           15  dac38808-0f6d-42c5-a0fc-b355e453db00
# 12           14                                   NaN
# 13           14                                   NaN
# 14           13  dac38808-0f6d-42c5-a0fc-b355e453db00
# 15           13  dac38808-0f6d-42c5-a0fc-b355e453db00
# 16           12                                   NaN
# 17           11                                   NaN
# 18           10                                   NaN
# 19           10                                   NaN
# 20           10                                   NaN
# 21            9  dac38808-0f6d-42c5-a0fc-b355e453db00
# 22            9  dac38808-0f6d-42c5-a0fc-b355e453db00
# 23            9  dac38808-0f6d-42c5-a0fc-b355e453db00
# 24            9  dac38808-0f6d-42c5-a0fc-b355e453db00
# 25            8  dac38808-0f6d-42c5-a0fc-b355e453db00
# 26            7                                   NaN
# 27            7                                   NaN
# 28            7                                   NaN
# 29            7                                   NaN
# 30            6                                   NaN
# 31            5                                   NaN
# 32            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 33            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 34            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 35            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 36            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 37            4  dac38808-0f6d-42c5-a0fc-b355e453db00
# 38            3                                   NaN
# 39            3                                   NaN
# 40            3                                   NaN
# 41            3                                   NaN
# 42            3                                   NaN
# 43            3                                   NaN
# 44            3                                   NaN
# 45            3                                   NaN
# 46            3                                   NaN
# 47            3                                   NaN
# 48            2                                   NaN
# 49            1                                   NaN
# 50            1                                   NaN
# 51            1                                   NaN
# 52            0                                   NaN
# 53            0                                   NaN
# 54            0                                   NaN

# %%
diar_df.head(50)
# Out:
#     diar_chunk                               start  \
# 0           19 2024-06-21 12:36:33.267352964+00:00
# 8   0e0b4403-963b-45cb-8605-07cae5a5ad70      38      0:38.000
# 9   dac38808-0f6d-42c5-a0fc-b355e453db00      60      1:00.000
# 10  dac38808-0f6d-42c5-a0fc-b355e453db00      62      1:02.000
# 11  dac38808-0f6d-42c5-a0fc-b355e453db00      69      1:09.000
# 12  dac38808-0f6d-42c5-a0fc-b355e453db00      75      1:15.000
# 13  dac38808-0f6d-42c5-a0fc-b355e453db00      79      1:19.000
# 14  dac38808-0f6d-42c5-a0fc-b355e453db00     120      2:00.000
# 15  dac38808-0f6d-42c5-a0fc-b355e453db00     121      2:01.000
# 16  dac38808-0f6d-42c5-a0fc-b355e453db00     135      2:15.000
# 17  73b2a3f1-9fa1-4a79-abd9-04f58c7bfdd5     135      2:15.000
# 18  dac38808-0f6d-42c5-a0fc-b355e453db00     200      3:20.000
# 19  dac38808-0f6d-42c5-a0fc-b355e453db00     300      5:00.000
# 20  dac38808-0f6d-42c5-a0fc-b355e453db00     300      5:00.000
# 21  dac38808-0f6d-42c5-a0fc-b355e453db00     301      5:01.000
# 22  dac38808-0f6d-42c5-a0fc-b355e453db00     303      5:03.000
# 23                                  None     314      5:14.000
# 24                                  None     314      5:14.000
# 25  dac38808-0f6d-42c5-a0fc-b355e453db00     316      5:16.000
# 26  dac38808-0f6d-42c5-a0fc-b355e453db00     420      7:00.000
# 27  73b2a3f1-9fa1-4a79-abd9-04f58c7bfdd5     424      7:04.000
# 28  dac38808-0f6d-42c5-a0fc-b355e453db00     424      7:04.000
# 29  dac38808-0f6d-42c5-a0fc-b355e453db00     560      9:20.000
# 30  dac38808-0f6d-42c5-a0fc-b355e453db00     562      9:22.000
# 31  dac38808-0f6d-42c5-a0fc-b355e453db00     564      9:24.000
# 32  dac38808-0f6d-42c5-a0fc-b355e453db00     571      9:31.000
# 33  dac38808-0f6d-42c5-a0fc-b355e453db00     573      9:33.000
# 34  dac38808-0f6d-42c5-a0fc-b355e453db00     575      9:35.000
# 35  dac38808-0f6d-42c5-a0fc-b355e453db00     577      9:37.000
# 36  dac38808-0f6d-42c5-a0fc-b355e453db00     720     12:00.000
# 37  0e0b4403-963b-45cb-8605-07cae5a5ad70     721     12:01.000
# 38  dac38808-0f6d-42c5-a0fc-b355e453db00     722     12:02.000
# 39  dac38808-0f6d-42c5-a0fc-b355e453db00     736     12:16.000
# 40  dac38808-0f6d-42c5-a0fc-b355e453db00     900     15:00.000
# 41  dac38808-0f6d-42c5-a0fc-b355e453db00     900     15:00.000
# 42  dac38808-0f6d-42c5-a0fc-b355e453db00     915     15:15.000
# 43  0e0b4403-963b-45cb-8605-07cae5a5ad70     919     15:19.000
# 44  0142f3ca-c8c3-4de0-8180-c5efd921e3fa    1100     18:20.000
# 45  0142f3ca-c8c3-4de0-8180-c5efd921e3fa    1104     18:24.000
# 46  0142f3ca-c8c3-4de0-8180-c5efd921e3fa    1109     18:29.000
# 47  0142f3ca-c8c3-4de0-8180-c5efd921e3fa    1117     18:37.000
# 48  0e0b4403-963b-45cb-8605-07cae5a5ad70    1320     22:00.000
# 49  0142f3ca-c8c3-4de0-8180-c5efd921e3fa    1320     22:00.000
#
#                   intersection
# 0  -1 days +23:53:29.851714771
# 1  -1 days +23:53:34.401799660
# 2  -1 days +23:53:35.029983022
# 3  -1 days +23:53:36.235415959
# 4  -1 days +23:53:47.033378608
# 5  -1 days +23:53:56.863599321
# 6  -1 days +23:53:58.782105263
# 7  -1 days +23:54:06.982444822
# 8  -1 days +23:54:05.997724958
# 9  -1 days +23:54:29.529134126
# 10 -1 days +23:54:35.709100170
# 11 -1 days +23:54:42.313514431
# 12 -1 days +23:54:46.388217317
# 13 -1 days +23:54:46.999422750
# 14 -1 days +23:55:28.391612903
# 15 -1 days +23:55:42.398404075
# 16 -1 days +23:55:46.676842105
# 17 -1 days +23:55:43.366146010
# 18 -1 days +23:57:07.016400679
# 19 -1 days +23:58:27.288047538
# 20 -1 days +23:58:27.831341256
# 21 -1 days +23:58:30.276162988
# 22 -1 days +23:58:42.262580645
# 23 -1 days +23:58:41.430662139
# 24 -1 days +23:58:43.383123939
# 25 -1 days +23:58:47.016400679
# 26 -1 days +23:59:40.011511036
# 27 -1 days +23:59:35.987741935
# 28 -1 days +23:59:35.970764007
# 29 -1 days +23:57:20.011511036
# 30 -1 days +23:57:17.651578947
# 31 -1 days +23:57:15.546315789
# 32 -1 days +23:57:08.143938879
# 33 -1 days +23:57:06.038675722
# 34 -1 days +23:57:04.493684211
# 35 -1 days +23:57:02.133752122
# 36 -1 days +23:54:40.011511036
# 37 -1 days +23:54:38.500475382
# 38 -1 days +23:54:37.736468591
# 39 -1 days +23:54:23.305229202
# 40 -1 days +23:51:40.011511036
# 41 -1 days +23:51:39.841731749
# 42 -1 days +23:51:24.527640068
# 43 -1 days +23:51:20.486893039
# 44 -1 days +23:48:20.011511036
# 45 -1 days +23:48:15.631205433
# 46 -1 days +23:48:10.283157895
# 47 -1 days +23:48:02.354465195
# 48 -1 days +23:44:40.011511036
# 49 -1 days +23:44:40.011511036

# %%
rename_dict = {
    
    'a1e24d98-918b-4633-8a4e-a4613949c0bc':'Ryabenko',
    '1c6cac3c-0eba-4404-a6fc-ab1f54992292':'Ikenna',
    'e92fd67c-d305-4bd4-a1d4-81dc86e2f063':'Me',
    'f39f85d8-2c76-4ee5-bb70-dc18f7c39af5':'Me',
    '7c0d4578-e6e2-4216-b3fa-bc9fa31162c9':'Me',
    '4384a580-e3d3-4b96-bd01-5412318bdbda':'ANdrew',
    'd22658aa-ab7a-4aea-a322-ff86c2274b18':'Olya',
    'feed0fdf-8332-4c6c-842d-b8fcc1543508':'Liza',
    '77270ffb-54a5-4a23-8b10-d273347a7233':'Egor',
    'e419df06-381b-4de1-a8aa-dca078326af8':'ANton',
    '1ccf5e92-978f-4fd6-861e-d21afcc4294c':'liza',
    '1cbc5a49-3521-4f67-8fbc-9601c50a6753':'David',
    '926bad2e-a55e-498e-9cef-68344f491d88':'Me',
    'be6ac578-3d51-435a-9d70-5f99f4e49c79':'Katz',
    '4cad8508-a340-4fdb-923b-0db5c632ebb2':'Dima Blaster',
    '5661486b-45e2-40d6-addb-17d59ad9832b':'Blasteritsa'


    

               
               }

segments_df['point_id'] = segments_df['point_id'].replace(rename_dict)
segments_df = segments_df.sort_values('start').reset_index(drop=True)
segments_df.tail(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'point_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 26
#       1 rename_dict = {
#       2
#       3     'a1e24d98-918b-4633-8a4e-a4613949c0bc':'Ryabenko',
#    (...)
#      23
#      24                }
# ---> 26 segments_df['point_id'] = segments_df['point_id'].replace(rename_dict)
#      27 segments_df = segments_df.sort_values('start').reset_index(drop=True)
#      28 segments_df.tail(50)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'point_id'

# %%
segments_df
# Out:
#     emb_id                               start  \
# 0       37 2024-06-20 18:59:01.039337964+00:00
# 1       36 2024-06-20 18:59:01.039337964+00:00
# 2       36 2024-06-20 18:59:05.029151207+00:00
# 3       38 2024-06-20 18:59:08.170068015+00:00
# 4       37 2024-06-20 18:59:08.204023873+00:00
# ..     ...                                 ...
# 61       4 2024-06-20 19:24:37.270237795+00:00
# 62       3 2024-06-20 19:27:31.039337964+00:00
# 63       2 2024-06-20 19:27:40.122529815+00:00
# 64       0 2024-06-20 19:30:41.039337964+00:00
# 65       1 2024-06-20 19:30:48.237979730+00:00
#
#                                    end  cluster  span  \
# 0  2024-06-20 18:59:02.618285333+00:00        0     1
# 1  2024-06-20 18:59:04.791460205+00:00        0     3
# 2  2024-06-20 18:59:10.343242888+00:00        0     5
# 3  2024-06-20 18:59:08.204023873+00:00        2     0
# 4  2024-06-20 18:59:08.577538304+00:00        0     0
# ..                                 ...      ...   ...
# 61 2024-06-20 19:24:41.022360036+00:00        6     3
# 62 2024-06-20 19:27:41.022360036+00:00        6     9
# 63 2024-06-20 19:27:40.920492463+00:00       12     0
# 64 2024-06-20 19:30:50.954448321+00:00        6     9
# 65 2024-06-20 19:30:48.696383805+00:00        7     0
#
#                                 point_id
# 0                                   liza
# 1                                   liza
# 2                                   liza
# 3                                   None
# 4                                   liza
# ..                                   ...
# 61  7a9b58aa-d154-40fb-a041-ae5ddcc77521
# 62  7a9b58aa-d154-40fb-a041-ae5ddcc77521
# 63                                  None
# 64  7a9b58aa-d154-40fb-a041-ae5ddcc77521
# 65                                  None
#
# [66 rows x 6 columns]
