# %%
from qdrant_client import QdrantClient
from qdrant_client.models import  Distance, VectorParams

client = QdrantClient(url="http://localhost:6333")

from qdrant_client.models import PointStruct
from uuid import uuid4
import json

# %%
import redis
redis_client = redis.Redis(host='localhost', port=6399, db=0,decode_responses=True)

# %%
class SpeechDAL:
    def get_all_transcriptions(self) -> list:
        # Get all data
        raw_data = redis_client.lrange(f"transcriber", start=0, end=-1)
        return [json.loads(data) for data in raw_data]

    def get_all_diarizations(self) -> list:
        # Get all data
        raw_data = redis_client.lrange(f"diarizer", start=0, end=-1)
        return [json.loads(data) for data in raw_data]

    def lpush_diarizations(self,diarizations: str) -> None:
        for d in diarizations:
            redis_client.lpush(f"diarizer", json.dumps(d))

    def lpush_transcriptions(self, transcriptions) -> None:
        for t in transcriptions:
            redis_client.lpush(f"transcriber", json.dumps(t))

    def ltrim_transcriptions(self, meeting_id, slice: tuple):
        redis_client.ltrim(f"diarizer", int(slice[0]), int(slice[1]))

    def ltrim_diarizations(self, meeting_id, slice: tuple):
        redis_client.ltrim(f"diarizer", int(slice[0]), int(slice[1]))

# %%
from pathlib import  Path
import torch
from pyannote.audio import Pipeline
import io
from audio import AudioSlicer
import pandas as pd

import numpy as np
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import matplotlib.pyplot as plt
import numpy as np
import random

Path.ls = lambda self:[item for item in self.iterdir()]

def parse_segment(segment):
    return segment[0].start, segment[0].end, int(segment[-1].split("_")[1])

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import pairwise_distances
from scipy.cluster.hierarchy import linkage, fcluster

# Configuration parameters
config = {
    'clustering': {
        'method': 'centroid',
        'min_cluster_size': 3,
        'threshold': 1.#0.7# 0.7045654963945799 #
    }
}

def centroid_linkage_distance(matrix):
    """Custom function to compute linkage with centroid method."""
    Z = linkage(matrix, method='centroid')
    return Z

def compute_centroids(embeddings, labels):
    """Compute centroids of clusters and return centroids in the order of labels."""
    unique_labels = np.unique(labels)
    centroids = np.zeros((len(unique_labels), embeddings.shape[1]))
    
    for i, label in enumerate(unique_labels):
        centroids[i] = embeddings[labels == label].mean(axis=0)
    
    return centroids, unique_labels

def map_labels_to_centroid_indices(labels, unique_labels):
    """Map labels to the indices of centroids."""
    label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
    centroid_indices = np.array([label_to_index[label] if label in unique_labels else -1 for label in labels])
    return centroid_indices

def cluster_embeddings(embeddings, config):
    distance_matrix = pairwise_distances(embeddings, metric='cosine')
    Z = centroid_linkage_distance(distance_matrix)
    labels = fcluster(Z, t=config['clustering']['threshold'], criterion='distance')
    unique_labels, counts = np.unique(labels, return_counts=True)
    valid_labels = unique_labels[counts >= config['clustering']['min_cluster_size']]
    valid_indices = np.where(np.isin(labels, valid_labels))[0]
    centroids, unique_labels = compute_centroids(embeddings, labels)
    centroid_indices = map_labels_to_centroid_indices(labels, unique_labels)
    valid_centroid_indices = np.array([index for index, centroid in enumerate(centroids) if index in np.unique(centroid_indices[valid_indices])])
    return centroid_indices, centroids, valid_centroid_indices

def find_largest_span(points):
    # Use max to find the point with the largest span
    largest_span_point = max(points, key=lambda p: p.payload['span'])
    return largest_span_point

# %%
def prep_diarization(diarization) -> pd.DataFrame:
    d, embs,seek = diarization
    df = pd.DataFrame(d)
    df["start"] = pd.to_timedelta(df["start"], unit="s") + pd.Timestamp(seek)
    df["end"] = pd.to_timedelta(df["end"], unit="s") + pd.Timestamp(seek)

    return df,embs

# %%
def prep_transcripts(transcriptions) -> pd.DataFrame:
    dfs = []
    for n, (t, seek) in enumerate(transcriptions):
        df = pd.DataFrame(t)[[2, 3, 4]]
        df.columns = ["start", "end", "speech"]
        df["start"] = pd.to_timedelta(df["start"], unit="s") + pd.Timestamp(seek)
        df["end"] = pd.to_timedelta(df["end"], unit="s") + pd.Timestamp(seek)
        df["trans_chunk"] = n
        dfs.append(df)
    return pd.concat(dfs).reset_index(drop=True)

# %%
class SpeakerIdentification:
    def __init__(self,config):
        self.config = config
        self.embeddings_list = []
        self.segments = []

    async def extract(self,diarization):
        segs,embs = prep_diarization(diarization)
        
        self.embeddings_list.append(embs)
        self.segments.append(segs)

        self.embeddings = np.concatenate(self.embeddings_list, axis=0)
        self.clusters,self.centroids,self.valid_clusters = cluster_embeddings(self.embeddings, self.config)
        self.df = pd.concat(self.segments)
        self.df = self.df.set_index('speaker_id').join(pd.DataFrame({'cluster':self.clusters})).reset_index(drop=True)
        self.df['span'] = self.df['end'] - self.df['start']
        cluster_span = self.df.groupby('cluster')[['span']].sum()
        self.cluster_span = cluster_span.to_dict()['span']
        
        

        
    def assing_speaker_ids(self):
        new_points = []
        for cluster in list(self.cluster_span.keys()):
            point_id = None

            centroid = self.centroids[cluster]
            search_results = client.search(collection_name="speakers", query_vector=list(centroid), limit=5,score_threshold=0.65)
            
            
            
            if len(search_results)==0:
                if cluster in self.valid_clusters:
                    point_id = str(uuid4())
                    new_points.append(PointStruct(id = point_id,vector = list(centroid),payload={"span":self.cluster_span[cluster]}))

            else:
                search_result = find_largest_span(search_results)
                point_id = search_result.id 
                remote_span = search_result.payload['span']
                

                span = self.cluster_span[cluster]
                span = span.seconds
                if span > remote_span:
                    new_points.append(PointStruct(id = point_id,vector = list(centroid),payload={"span":span}))  
                    
            self.df.loc[self.df['cluster']==cluster,'speaker'] = point_id
                    
        if len(new_points)>0:
            operation_info = client.upsert(
                collection_name="speakers",
                wait=True,
                points=new_points
            )    
        self.df = self.df.sort_values('start').reset_index(drop=True)
        
        return self.df
    
    
    async def process_diarizations(self,diarizations):
        for d in diarizations:
            await self.extract(d)
            self.diar_df = self.assing_speaker_ids()
        return self.diar_df
            
    def merge(self,diar_df,trans_df):
        segments = trans_df.to_dict("records")

        if len(segments) > 0:
            for seg in segments:
                diar_df["intersection"] = np.minimum(diar_df["end"], seg["end"]) - np.maximum(
                    diar_df["start"], seg["start"]
                )
                speaker_ = diar_df[
                    (diar_df["intersection"] == diar_df["intersection"].max())
                    & (diar_df["intersection"] > pd.Timedelta(0))
                ][["speaker"]]
                if len(speaker_) > 0:
                    seg["speaker"] = speaker_["speaker"].iloc[0]


                # ToDo: Dima
                else:
                    seg["speaker"] = np.nan

        return pd.DataFrame(segments).sort_values('start').reset_index(drop=True)

# %%
merger = SpeakerIdentification(config)

# %%
speech_dal = SpeechDAL()
diarizations = speech_dal.get_all_diarizations()
transcriptions = speech_dal.get_all_transcriptions()

# %%
trans_df = prep_transcripts(transcriptions)

# %%
diar_df = await merger.process_diarizations(diarizations)

# %%
merger.merge(diar_df,trans_df).replace({id:n for n,id in enumerate(diar_df['speaker'].unique().tolist())})
# Out:
#                               start                              end  \
# 0  2024-06-21 12:36:53.368864+00:00 2024-06-21 12:36:56.108864+00:00
# 1  2024-06-21 12:36:57.248864+00:00 2024-06-21 12:36:59.268864+00:00
# 2  2024-06-21 12:37:02.108864+00:00 2024-06-21 12:37:04.688864+00:00
# 3  2024-06-21 12:37:04.708864+00:00 2024-06-21 12:37:07.548864+00:00
# 4  2024-06-21 12:37:08.668864+00:00 2024-06-21 12:37:10.128864+00:00
# 5  2024-06-21 12:37:11.408864+00:00 2024-06-21 12:37:13.148864+00:00
# 6  2024-06-21 12:37:13.258864+00:00 2024-06-21 12:37:15.498864+00:00
# 7  2024-06-21 12:37:15.518864+00:00 2024-06-21 12:37:18.058864+00:00
# 8  2024-06-21 12:37:18.058864+00:00 2024-06-21 12:37:19.758864+00:00
# 9  2024-06-21 12:37:20.658864+00:00 2024-06-21 12:37:21.218864+00:00
# 10 2024-06-21 12:37:22.318864+00:00 2024-06-21 12:37:22.878864+00:00
# 11 2024-06-21 12:37:24.178864+00:00 2024-06-21 12:37:25.318864+00:00
# 12 2024-06-21 12:37:29.178864+00:00 2024-06-21 12:37:30.298864+00:00
# 13 2024-06-21 12:37:31.478864+00:00 2024-06-21 12:37:32.598864+00:00
# 14 2024-06-21 12:37:32.598864+00:00 2024-06-21 12:37:33.138864+00:00
# 15 2024-06-21 12:37:33.258864+00:00 2024-06-21 12:37:36.118864+00:00
# 16 2024-06-21 12:37:36.238864+00:00 2024-06-21 12:37:36.998864+00:00
# 17 2024-06-21 12:37:41.578864+00:00 2024-06-21 12:37:42.238864+00:00
# 18 2024-06-21 12:37:44.018864+00:00 2024-06-21 12:37:46.038864+00:00
# 19 2024-06-21 12:37:46.218864+00:00 2024-06-21 12:37:50.958864+00:00
# 20 2024-06-21 12:37:53.258864+00:00 2024-06-21 12:37:56.898864+00:00
# 21 2024-06-21 12:37:59.638864+00:00 2024-06-21 12:38:13.238864+00:00
# 22 2024-06-21 12:38:13.718864+00:00 2024-06-21 12:38:16.038864+00:00
# 23 2024-06-21 12:38:17.318864+00:00 2024-06-21 12:38:33.178864+00:00
# 24 2024-06-21 12:38:34.098864+00:00 2024-06-21 12:38:53.038864+00:00
# 25 2024-06-21 12:38:53.258864+00:00 2024-06-21 12:39:13.058864+00:00
# 26 2024-06-21 12:39:13.878864+00:00 2024-06-21 12:39:33.038864+00:00
# 1                     По спикерам давай, по диарайзу.           19        1
# 2    Последний день перед отпуском на основной раб...           19        1
# 3        Блин, то по носу, то золотом. Все мое, блин.           19        1
# 4                              У тебя два дня отпуск?           19        0
# 5                     Нет, у меня четыре со вторника.           19        0
# 6                      по пятницу на основной работе,           18        1
# 7                                   а здесь я отдохну           18        1
# 8          в среду, в четверг, завтра я в строю буду.           18        1
# 9                                                Ага.           18        0
# 10                                              Окей.           18        0
# 11                                     Так, ну ладно.           18        0
# 12                                      Так, ну давай           18        0
# 13                                   просто посмотрим           18        0
# 14                                               код.           18        0
# 15   и подумают, что с ним делать, например, вот так.           17        0
# 16                                        Угу, давай.           17        1
# 17                                          Ага, все.           17        1
# 18                           Вот, что у нас тут есть?           17        0
# 19   Ну, у нас есть вот этот вектор store, который...           17        0
# 20                 в отдельном в отдельном контейнере           16        1
# 21   как обычно это нам здесь нужно так чисто для ...           16        1
# 22             Это все там, где ты скинул, да, в 0.2.           15        1
# 23   Да, здесь все, здесь end-to-end все есть. Вот...           15        1
# 24   Вот, видишь, получил какое-то, вот какие-то л...           14        0
# 25   И вот этот вот уже кластер, который есть, это...           13        1
# 26   Вот. Идем дальше. Лиза что-то говорит. Лиза, ...           12        1
# 27                                        На секунду.           11        1
# 28                         Да, но он не успел понять.           11        0
# 29                             Это подача на систему.           11        1
# 30                           Ну, это однозначно Лиза.           11        1
# 31    Да, ну вот дальше Лиза, Лиза, Лиза, Лиза, Лиза.           11        1
# 32            Ну вот, кто-то опять что-то там сказал.           11        1
# 33                                      Или это 28...           11        1
# 34   Ну, тут понятно, тут будут, мне, наверное, ну...           10        1
# 35   Мачется с транскрипциями. Вот видишь, ну вот ...            9        1
# 36   например может быть она неправильно запустила...            8        1
# 37   запустила ту предыдущую она вот здесь вот он ...            8        1
# 38   кластер кластер маленький поэтому нам вот зде...            8        1
# 39           кто-то новый говорит, кого он не слышал.            7        0
# 40                        Видишь, одинаковый ID-шник.            7        0
# 41                                     Что это такое?            7        1
# 42                                       Это снижение            7        0
# 43                                     из интеграции.            7        1
# 44                              Я узнаю этого чувака.            7        1
# 45                                         Это Дэвид.            7        1
# 46                                         Это Дэвид.            7        1
# 47   Дэвид, Дэвид, я его запишу как Дэвид, возьму ...            6        1
# 48   распознать, потому что здесь я тоже в этой вс...            6        0
# 49                                            встречу            5        1
# 50   а это кусочек этой встречи сюда закинул вот н...            4        0
# 51   посмотрю как это мочится с виспером вот в цел...            4        0
# 52       Что здесь нам нужно сделать? Давай прикинем.            3        0
# 53   Ну смотри, в идеале для начала определиться, ...            3        1
# 54    Она заканчивается раньше, чем до этого сервиса.            3        0
# 55   Сейчас она будет возвращать, вот видишь, вот ...            2        1
# 56   но смотря на аудио сервисе до этого имбединги...            1        1
# 57   тут видишь я до этого за аудио сервису сейчас...            1        1
# 58                            вытаскивал имбединги из            1        0
# 59   Из этого самого, из VectorStore. Здесь будет ...            0        1
